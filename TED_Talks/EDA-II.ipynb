# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('archive/2020-05-01/ted_talks_en.csv')

# %%
df
# Out:
#       talk_id                                             title  \
# 0           1                       Averting the climate crisis
# 1          92                   The best stats you've ever seen
# 2           7                                  Simplicity sells
# 3          53                               Greening the ghetto
# 4          66                       Do schools kill creativity?
# ...       ...                                               ...
# 4000    62678       Crisis support for the world, one text away
# 4001    62782                      The dark history of IQ tests
# 4002    62263  How "policing for profit" undermines your rights
# 4003    62784      The electrifying speeches of Sojourner Truth
# 4004    62794              The most important anus in the ocean
#
#                  speaker_1                 all_speakers  \
# 0                  Al Gore               {0: 'Al Gore'}
# 1             Hans Rosling          {0: 'Hans Rosling'}
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4005 entries, 0 to 4004
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   talk_id         4005 non-null   int64
#  1   title           4005 non-null   object
#  2   speaker_1       4005 non-null   object
#  3   all_speakers    4001 non-null   object
#  4   occupations     3483 non-null   object
#  5   about_speakers  3502 non-null   object
#  6   views           4005 non-null   int64
#  7   recorded_date   4004 non-null   object
#  8   published_date  4005 non-null   object
#  9   event           4005 non-null   object
#  10  native_lang     4005 non-null   object
#  11  available_lang  4005 non-null   object
#  12  comments        3350 non-null   float64
#  13  duration        4005 non-null   int64
#  14  topics          4005 non-null   object
#  15  related_talks   4005 non-null   object
#  16  url             4005 non-null   object
# ...

# %%
df['recorded_date'] = pd.to_datetime(df['recorded_date'])
df['published_date'] = pd.to_datetime(df['published_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4005 entries, 0 to 4004
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   talk_id         4005 non-null   int64
#  1   title           4005 non-null   object
#  2   speaker_1       4005 non-null   object
#  3   all_speakers    4001 non-null   object
#  4   occupations     3483 non-null   object
#  5   about_speakers  3502 non-null   object
#  6   views           4005 non-null   int64
#  7   recorded_date   4004 non-null   datetime64[ns]
#  8   published_date  4005 non-null   datetime64[ns]
#  9   event           4005 non-null   object
#  10  native_lang     4005 non-null   object
#  11  available_lang  4005 non-null   object
#  12  comments        3350 non-null   float64
#  13  duration        4005 non-null   int64
#  14  topics          4005 non-null   object
#  15  related_talks   4005 non-null   object
#  16  url             4005 non-null   object
# ...

# %%
df
# Out:
#       talk_id                                             title  \
# 0           1                       Averting the climate crisis
# 1          92                   The best stats you've ever seen
# 2           7                                  Simplicity sells
# 3          53                               Greening the ghetto
# 4          66                       Do schools kill creativity?
# ...       ...                                               ...
# 4000    62678       Crisis support for the world, one text away
# 4001    62782                      The dark history of IQ tests
# 4002    62263  How "policing for profit" undermines your rights
# 4003    62784      The electrifying speeches of Sojourner Truth
# 4004    62794              The most important anus in the ocean
#
#                  speaker_1                 all_speakers  \
# 0                  Al Gore               {0: 'Al Gore'}
# 1             Hans Rosling          {0: 'Hans Rosling'}
# ...

# %%
columns = ['views', 'recorded_date', 'published_date', 'comments', 'duration']

# %%
df[columns]
# Out:
#          views recorded_date published_date  comments  duration
# 0      3523392    2006-02-25     2006-06-27     272.0       977
# 1     14501685    2006-02-22     2006-06-27     628.0      1190
# 2      1920832    2006-02-24     2006-06-27     124.0      1286
# 3      2664069    2006-02-26     2006-06-27     219.0      1116
# 4     65051954    2006-02-25     2006-06-27    4931.0      1164
# ...        ...           ...            ...       ...       ...
# 4000    502934    2020-04-22     2020-04-27       6.0       690
# 4001    307187    2020-04-27     2020-04-27       NaN       346
# 4002    464414    2019-06-22     2020-04-28       9.0       774
# 4003     56582    2020-04-28     2020-04-30       NaN       257
# 4004         0    2020-04-30     2020-04-30       NaN       281
#
# [4005 rows x 5 columns]

# %%
df[columns].describe()
# Out:
#               views                  recorded_date  \
# count  4.005000e+03                           4004
# mean   2.148006e+06  2014-03-21 15:24:38.121878272
# min    0.000000e+00            1984-02-02 00:00:00
# 25%    8.820690e+05            2011-07-12 00:00:00
# 50%    1.375508e+06            2014-10-09 00:00:00
# 75%    2.133110e+06            2017-10-17 00:00:00
# max    6.505195e+07            2020-04-30 00:00:00
# std    3.451226e+06                            NaN
#
#                       published_date     comments     duration
# count                           4005  3350.000000  4005.000000
# mean   2015-01-23 07:41:18.202247168   161.997015   724.011236
# min              2006-06-27 00:00:00     0.000000    60.000000
# 25%              2011-10-31 00:00:00    38.000000   393.000000
# 50%              2015-09-29 00:00:00    89.000000   738.000000
# 75%              2018-10-24 00:00:00   188.000000   974.000000
# ...

# %%
df = df[df['comments'] > 40]
df = df[df['duration'] > 350]

# %%
df
# Out:
#       talk_id                                              title  \
# 0           1                        Averting the climate crisis
# 1          92                    The best stats you've ever seen
# 2           7                                   Simplicity sells
# 3          53                                Greening the ghetto
# 4          66                        Do schools kill creativity?
# ...       ...                                                ...
# 3928    60084  What we do (and don't) know about the coronavirus
# 3946    60872  Why COVID-19 is hitting us now -- and how to p...
# 3960    61301    How we must respond to the coronavirus pandemic
# 3966    61302  What the world can learn from China's response...
# 3982    62266      What coronavirus means for the global economy
#
#              speaker_1                                       all_speakers  \
# 0              Al Gore                                     {0: 'Al Gore'}
# ...

# %%
df[columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2239 entries, 0 to 3982
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   views           2239 non-null   int64
#  1   recorded_date   2239 non-null   datetime64[ns]
#  2   published_date  2239 non-null   datetime64[ns]
#  3   comments        2239 non-null   float64
#  4   duration        2239 non-null   int64
# dtypes: datetime64[ns](2), float64(1), int64(2)
# memory usage: 105.0 KB

# %%
df.shape
# Out:
# (2239, 19)

# %%
df[columns].describe()
# Out:
#               views                  recorded_date  \
# count  2.239000e+03                           2239
# mean   2.567921e+06  2012-07-08 08:44:48.343010304
# min    1.065450e+05            1984-02-02 00:00:00
# 25%    1.028948e+06            2010-04-13 12:00:00
# 50%    1.538259e+06            2012-06-28 00:00:00
# 75%    2.484150e+06            2015-04-15 00:00:00
# max    6.505195e+07            2020-04-08 00:00:00
# std    4.181138e+06                            NaN
#
#                       published_date     comments     duration
# count                           2239  2239.000000  2239.000000
# mean   2013-02-05 14:29:31.862438656   216.626172   884.673068
# min              2006-06-27 00:00:00    41.000000   351.000000
# 25%              2010-07-28 12:00:00    77.500000   678.000000
# 50%              2012-12-13 00:00:00   132.000000   893.000000
# 75%              2015-09-15 12:00:00   239.000000  1066.000000
# ...

# %%
df[['views', 'comments', 'duration']].quantile([0.20, 0.80])
# Out:
#          views  comments  duration
# 0.2   905717.2      70.0     617.0
# 0.8  2909728.8     283.4    1099.0

# %%
df[['views', 'comments']].corr()
# Out:
#              views  comments
# views     1.000000  0.478287
# comments  0.478287  1.000000

# %%
df['engagement_rate'] = df['comments'] / df['views']

# %%
columns.append('engagement_rate')

# %%
df[columns]
# Out:
#          views recorded_date published_date  comments  duration  \
# 0      3523392    2006-02-25     2006-06-27     272.0       977
# 1     14501685    2006-02-22     2006-06-27     628.0      1190
# 2      1920832    2006-02-24     2006-06-27     124.0      1286
# 3      2664069    2006-02-26     2006-06-27     219.0      1116
# 4     65051954    2006-02-25     2006-06-27    4931.0      1164
# ...        ...           ...            ...       ...       ...
# 3928   1960247    2020-02-27     2020-03-03      46.0       486
# 3946   2559523    2020-03-06     2020-03-16     177.0       979
# 3960   6144695    2020-03-24     2020-03-25     230.0      3110
# 3966   1242418    2020-03-25     2020-03-27     169.0      3503
# 3982   1579481    2020-04-08     2020-04-09      58.0      3160
#
#       engagement_rate
# 0            0.000077
# 1            0.000043
# 2            0.000065
# 3            0.000082
# 4            0.000076
# ...               ...
# 3928         0.000023
# ...

# %%
df['log_views'] = np.log1p(df['views'])

# %%
plt.scatter(df['duration'], df['views'])

# %%
df['publish_delay'] = (df['published_date'] - df['recorded_date']).dt.days

# %%
df['publish_delay'].describe()
# Out:
# count    2239.000000
# mean      212.239393
# std       470.668065
# min      -578.000000
# 25%        43.000000
# 50%        91.000000
# 75%       174.000000
# max      8804.000000
# Name: publish_delay, dtype: float64
